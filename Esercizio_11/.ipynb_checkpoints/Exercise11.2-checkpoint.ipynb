# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 1000)
x_valid = np.random.uniform(-1, 1, 100)
x_valid.sort()
y_target = 4 - 3 * x_valid - 2 * x_valid**2 + 3 * x_valid**3 # ideal (target) 

sigma = 0.2 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(4 - 3 * x_train - 2 * x_train**2 + 3 * x_train**3, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(4 - 3 * x_valid - 2 * x_valid**2 + 3 * x_valid**3, sigma) 

# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(10, input_shape=(1,), activation='elu'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_103 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_104 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_105 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=x_train, y=y_train, 
          batch_size=64, epochs=20,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/20
# 1000/1000 [==============================] - 2s 2ms/step - loss: 4.1099 - mean_squared_error: 4.1099 - val_loss: 0.6843 - val_mean_squared_error: 0.6843
# Epoch 2/20
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.5640 - mean_squared_error: 0.5640 - val_loss: 0.6004 - val_mean_squared_error: 0.6004
# Epoch 3/20
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.4736 - mean_squared_error: 0.4736 - val_loss: 0.6210 - val_mean_squared_error: 0.6210
# Epoch 4/20
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.4528 - mean_squared_error: 0.4528 - val_loss: 0.6211 - val_mean_squared_error: 0.6211
# Epoch 5/20
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.4423 - mean_squared_error: 0.4423 - val_loss: 0.6220 - val_mean_squared_error: 0.6220
# Epoch 6/20
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.4336 - mean_squared_error: 0.4336 - val_loss: 0.6217 - val_mean_squared_error: 0.6217
# Epoch 7/20
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.4258 - mean_squared_error: 0.4258 - val_loss: 0.6150 - val_mean_squared_error: 0.6150
# Epoch 8/20
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.4186 - mean_squared_error: 0.4186 - val_loss: 0.6058 - val_mean_squared_error: 0.6058
# Epoch 9/20
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.4112 - mean_squared_error: 0.4112 - val_loss: 0.5945 - val_mean_squared_error: 0.5945
# Epoch 10/20
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.4029 - mean_squared_error: 0.4029 - val_loss: 0.5851 - val_mean_squared_error: 0.5851
# Epoch 11/20
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.3940 - mean_squared_error: 0.3940 - val_loss: 0.5659 - val_mean_squared_error: 0.5659
# Epoch 12/20
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.3861 - mean_squared_error: 0.3861 - val_loss: 0.5509 - val_mean_squared_error: 0.5509
# Epoch 13/20
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.3767 - mean_squared_error: 0.3767 - val_loss: 0.5327 - val_mean_squared_error: 0.5327
# Epoch 14/20
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.3677 - mean_squared_error: 0.3677 - val_loss: 0.5231 - val_mean_squared_error: 0.5231
# Epoch 15/20
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.3582 - mean_squared_error: 0.3582 - val_loss: 0.5051 - val_mean_squared_error: 0.5051
# Epoch 16/20
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.3480 - mean_squared_error: 0.3480 - val_loss: 0.4884 - val_mean_squared_error: 0.4884
# Epoch 17/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.3379 - mean_squared_error: 0.3379 - val_loss: 0.4856 - val_mean_squared_error: 0.4856
# Epoch 18/20
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.3279 - mean_squared_error: 0.3279 - val_loss: 0.4620 - val_mean_squared_error: 0.4620
# Epoch 19/20
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.3184 - mean_squared_error: 0.3184 - val_loss: 0.4441 - val_mean_squared_error: 0.4441
# Epoch 20/20
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.3079 - mean_squared_error: 0.3079 - val_loss: 0.4399 - val_mean_squared_error: 0.4399

# %%
#model.evaluate(x_valid, y_valid, batch_size=32)
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# look into training history

# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])  #plt.plot(history.history['val_acc'])
plt.ylabel('error')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 100/100 [==============================] - 0s 66us/step
#
# Test loss: 0.4399422520399094
# Test accuracy: 0.4399422520399094

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
