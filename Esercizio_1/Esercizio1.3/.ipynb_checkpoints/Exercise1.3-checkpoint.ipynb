# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, y, error = np.loadtxt("Pi.txt", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(x,y,yerr=error)
plt.xlabel('#throws')
plt.ylabel('$\pi$')
plt.grid(True)
plt.show()
